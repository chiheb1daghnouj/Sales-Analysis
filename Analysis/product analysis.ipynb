# %%
# %load_ext sql
import urllib.parse

# %%
host = 'localhost'
user = 'postgres'
dbname = 'olist'
password = urllib.parse.quote_from_bytes('CHiheb 10'.encode())
conn_string = f"postgresql://{user}:{password}@{host}/{dbname}"

# %%
# %sql $conn_string

# %% [markdown]
# #  Exploration

# %%
# %%sql
# select * from products limit 10;
# Out:
#  * postgresql://postgres:***@localhost/olist
# 10 rows affected.
# [('1e9e8ef04dbcff4541ed26657ea517e5', 'perfumaria', 40, 287, 1, 225, 16, 10, 14),
#  ('3aa071139cb16b67ca9e5dea641aaa2f', 'artes', 44, 276, 1, 1000, 30, 18, 20),
#  ('96bd76ec8810374ed1b65e291975717f', 'esporte_lazer', 46, 250, 1, 154, 18, 9, 15),
#  ('cef67bcfe19066a932b7673e239eb23d', 'bebes', 27, 261, 1, 371, 26, 4, 26),
#  ('9dc1a7de274444849c219cff195d0b71', 'utilidades_domesticas', 37, 402, 4, 625, 20, 17, 13),
#  ('41d3672d4792049fa1779bb35283ed13', 'instrumentos_musicais', 60, 745, 1, 200, 38, 5, 11),
#  ('732bd381ad09e530fe0a5f457d81becb', 'cool_stuff', 56, 1272, 4, 18350, 70, 24, 44),
#  ('2548af3e6e77a690cf3eb6368e9ab61e', 'moveis_decoracao', 56, 184, 2, 900, 40, 8, 40),
#  ('37cc742be07708b53a98702e77a21a02', 'eletrodomesticos', 57, 163, 1, 400, 27, 13, 17),
#  ('8c92109888e8cdf9d66dc7e463025574', 'brinquedos', 36, 1156, 1, 600, 17, 10, 12)]

# %%
# %%sql
# select count(*) as total_products,
#         sum(case when product_name_length is null then 1 else 0 end) as nbr_null_name,
#         ((sum(case when product_name_length is null then 1 else 0 end)::real/count(*))*100)::real as percentage_null_value
# from products;
# Out:
#  * postgresql://postgres:***@localhost/olist
# 1 rows affected.
# [(32951, 610, 1.8512336)]

# %% [markdown]
# # Average length of name and description by category

# %%
# %%sql
#
# select product_category,avg(product_name_length)::int as avg_name_length , avg(product_desc_length)::int as avg_desc_length
# from products
# where product_category is not null
# group by product_category
# order by avg_name_length asc;
# Out:
#  * postgresql://postgres:***@localhost/olist
# 73 rows affected.
# [('fashion_roupa_masculina', 40, 627),
#  ('fashion_roupa_feminina', 40, 639),
#  ('livros_interesse_geral', 40, 989),
#  ('livros_tecnicos', 42, 1352),
#  ('moveis_colchao_e_estofado', 43, 1111),
#  ('market_place', 44, 829),
#  ('artes_e_artesanato', 44, 620),
#  ('artigos_de_natal', 44, 412),
#  ('consoles_games', 44, 850),
#  ('bebidas', 44, 1048),
#  ('moveis_sala', 44, 625),
#  ('alimentos_bebidas', 45, 983),
#  ('brinquedos', 45, 686),
#  ('perfumaria', 45, 694),
#  ('fashion_bolsas_e_acessorios', 45, 513),
#  ('fashion_roupa_infanto_juvenil', 45, 351),
#  ('alimentos', 46, 1137),
#  ('bebes', 46, 824),
#  ('moveis_escritorio', 46, 1353),
#  ('fraldas_higiene', 46, 488),
#  ('moveis_quarto', 46, 740),
#  ('dvds_blu_ray', 46, 1071),
#  ('fashion_esporte', 46, 556),
#  ('moveis_cozinha_area_de_servico_jantar_e_jardim', 47, 726),
#  ('esporte_lazer', 47, 954),
#  ('musica', 47, 1060),
#  ('beleza_saude', 47, 1137),
#  ('audio', 47, 782),
#  ('eletronicos', 47, 709),
#  ('artes', 47, 678),
#  ('malas_acessorios', 47, 633),
#  ('livros_importados', 47, 581),
#  ('cds_dvds_musicais', 47, 117),
#  ('telefonia_fixa', 48, 1017),
#  ('informatica_acessorios', 48, 774),
#  ('utilidades_domesticas', 48, 674),
#  ('sinalizacao_e_seguranca', 48, 817),
#  ('eletrodomesticos_2', 48, 798),
#  ('construcao_ferramentas_jardim', 48, 1135),
#  ('cool_stuff', 48, 876),
#  ('ferramentas_jardim', 49, 815),
#  ('artigos_de_festas', 49, 446),
#  ('pet_shop', 49, 866),
#  ('construcao_ferramentas_ferramentas', 49, 708),
#  ('agro_industria_e_comercio', 49, 808),
#  ('eletroportateis', 49, 934),
#  ('telefonia', 50, 755),
#  ('fashion_calcados', 50, 458),
#  ('papelaria', 50, 439),
#  ('instrumentos_musicais', 50, 795),
#  ('moveis_decoracao', 50, 799),
#  ('relogios_presentes', 50, 612),
#  ('construcao_ferramentas_construcao', 51, 789),
#  ('cine_foto', 51, 939),
#  ('casa_construcao', 51, 855),
#  ('casa_conforto_2', 52, 394),
#  ('cama_mesa_banho', 52, 464),
#  ('la_cuisine', 52, 422),
#  ('seguros_e_servicos', 52, 484),
#  ('construcao_ferramentas_iluminacao', 52, 788),
#  ('flores', 52, 468),
#  ('fashion_underwear_e_moda_praia', 52, 1004),
#  ('climatizacao', 52, 903),
#  ('automotivo', 52, 814),
#  ('construcao_ferramentas_seguranca', 52, 1106),
#  ('casa_conforto', 53, 320),
#  ('industria_comercio_e_negocios', 53, 1103),
#  ('portateis_casa_forno_e_cafe', 53, 1046),
#  ('portateis_cozinha_e_preparadores_de_alimentos', 54, 623),
#  ('eletrodomesticos', 54, 405),
#  ('tablets_impressao_imagem', 54, 676),
#  ('pcs', 56, 2129),
#  ('pc_gamer', 60, 998)]

# %% [markdown]
# #  Average weight, length, height, width by  product category

# %%
# %%sql
#
# select product_category, ROUND((avg(product_weight_grams)/1000)::decimal,3) as avg_weight_kg, avg(product_length_cm)::real as avg_length_cm, avg(product_height_cm)::real as avg_height_cm, avg(product_width_cm)::real as avg_width_cm
# from products
# where product_category is not null
# group by product_category;
# Out:
#  * postgresql://postgres:***@localhost/olist
# 73 rows affected.
# [('climatizacao', Decimal('4.460'), 36.467743, 23.887096, 26.088709),
#  ('livros_importados', Decimal('0.597'), 29.741936, 3.451613, 21.225807),
#  ('artigos_de_natal', Decimal('1.850'), 28.23077, 16.215385, 22.830769),
#  ('livros_tecnicos', Decimal('1.108'), 27.325203, 5.869919, 18.463415),
#  ('ferramentas_jardim', Decimal('3.104'), 30.936255, 19.204515, 23.504648),
#  ('cine_foto', Decimal('0.796'), 27.642857, 11.571428, 18.178572),
#  ('dvds_blu_ray', Decimal('0.382'), 21.270834, 4.4166665, 14.875),
#  ('fashion_roupa_feminina', Decimal('0.572'), 23.296297, 11.481482, 18.333334),
#  ('beleza_saude', Decimal('1.435'), 23.800737, 15.712357, 17.997545),
#  ('livros_interesse_geral', Decimal('0.747'), 23.481482, 9.773149, 19.328703),
#  ('tablets_impressao_imagem', Decimal('0.381'), 28.11111, 9.444445, 21.555555),
#  ('papelaria', Decimal('1.763'), 29.062426, 19.586573, 23.34629),
#  ('bebes', Decimal('3.655'), 37.14706, 21.617647, 28.717865),
#  ('musica', Decimal('1.214'), 27.148148, 9.925926, 18.222221),
#  ('consoles_games', Decimal('0.637'), 21.791798, 12.640379, 18.473186),
#  ('eletrodomesticos', Decimal('1.980'), 29.805405, 14.8918915, 21.859459),
#  ('cama_mesa_banho', Decimal('2.456'), 36.77418, 14.091119, 30.589964),
#  ('la_cuisine', Decimal('4.350'), 67.3, 13.8, 34.8),
#  ('seguros_e_servicos', Decimal('0.813'), 26.5, 28.5, 13.0),
#  ('artes_e_artesanato', Decimal('1.165'), 28.368422, 9.789474, 21.052631),
#  ('construcao_ferramentas_iluminacao', Decimal('2.281'), 27.846153, 20.423077, 25.73077),
#  ('eletroportateis', Decimal('4.012'), 29.47186, 27.038961, 27.30736),
#  ('malas_acessorios', Decimal('3.723'), 35.74212, 29.584528, 30.707737),
#  ('flores', Decimal('1.404'), 21.714285, 15.571428, 16.714285),
#  ('artigos_de_festas', Decimal('2.706'), 32.307693, 16.5, 22.73077),
#  ('sinalizacao_e_seguranca', Decimal('2.970'), 30.505377, 23.892473, 20.817204),
#  ('alimentos', Decimal('0.923'), 21.292683, 14.682927, 17.719513),
#  ('casa_construcao', Decimal('3.396'), 29.328888, 24.377777, 23.457777),
#  ('telefonia', Decimal('0.237'), 18.432981, 6.8536153, 13.248677),
#  ('esporte_lazer', Decimal('2.025'), 31.280085, 18.10987, 20.824207),
#  ('moveis_quarto', Decimal('9.997'), 59.933334, 30.8, 34.4),
#  ('moveis_sala', Decimal('8.935'), 50.73077, 22.365385, 44.429485),
#  ('moveis_colchao_e_estofado', Decimal('13.190'), 46.3, 34.4, 41.3),
#  ('construcao_ferramentas_construcao', Decimal('3.550'), 29.795, 15.895, 24.2425),
#  ('fashion_underwear_e_moda_praia', Decimal('0.362'), 25.509434, 8.849056, 18.90566),
#  ('moveis_decoracao', Decimal('3.008'), 43.894993, 17.438087, 28.663155),
#  ('portateis_cozinha_e_preparadores_de_alimentos', Decimal('2.518'), 28.5, 25.3, 24.6),
#  ('fashion_esporte', Decimal('0.345'), 22.105263, 12.842105, 16.263159),
#  ('alimentos_bebidas', Decimal('1.308'), 23.403847, 15.951923, 18.39423),
#  ('moveis_cozinha_area_de_servico_jantar_e_jardim', Decimal('11.599'), 47.340427, 40.47872, 38.68085),
#  ('pc_gamer', Decimal('1.430'), 17.666666, 20.0, 20.0),
#  ('bebidas', Decimal('1.736'), 23.91358, 22.37037, 19.395061),
#  ('market_place', Decimal('1.544'), 26.759615, 17.625, 22.490385),
#  ('fashion_roupa_masculina', Decimal('0.560'), 27.326315, 14.021052, 22.11579),
#  ('fashion_calcados', Decimal('1.045'), 26.028902, 13.381503, 24.947977),
#  ('casa_conforto_2', Decimal('1.468'), 53.2, 15.2, 26.2),
#  ('eletronicos', Decimal('1.275'), 25.237911, 11.736944, 18.468084),
#  ('audio', Decimal('0.642'), 20.827587, 11.5, 17.344828),
#  ('construcao_ferramentas_jardim', Decimal('2.401'), 28.693182, 16.65909, 20.511364),
#  ('artes', Decimal('1.692'), 35.927273, 11.8, 23.363636),
#  ('automotivo', Decimal('2.655'), 34.05, 16.24158, 23.382105),
#  ('cool_stuff', Decimal('2.567'), 33.752853, 22.988594, 24.491762),
#  ('industria_comercio_e_negocios', Decimal('5.929'), 39.058823, 32.514706, 29.220589),
#  ('pcs', Decimal('7.995'), 32.133335, 34.333332, 40.1),
#  ('agro_industria_e_comercio', Decimal('5.263'), 36.527027, 28.945946, 25.81081),
#  ('casa_conforto', Decimal('3.800'), 39.198196, 20.045046, 33.414413),
#  ('pet_shop', Decimal('3.089'), 32.98053, 20.126564, 26.749653),
#  ('moveis_escritorio', Decimal('12.741'), 55.62783, 41.86408, 37.919094),
#  ('fashion_roupa_infanto_juvenil', Decimal('0.324'), 27.4, 13.4, 20.6),
#  ('informatica_acessorios', Decimal('0.898'), 25.039658, 12.461257, 18.14338),
#  ('portateis_casa_forno_e_cafe', Decimal('3.072'), 31.32258, 22.838709, 23.870968),
#  ('telefonia_fixa', Decimal('0.661'), 20.646551, 10.74138, 16.5),
#  ('utilidades_domesticas', Decimal('3.021'), 31.859957, 22.337902, 24.821413),
#  ('instrumentos_musicais', Decimal('3.361'), 36.276817, 16.854671, 29.84429),
#  ('relogios_presentes', Decimal('0.509'), 19.222723, 10.292702, 15.268623),
#  ('construcao_ferramentas_ferramentas', Decimal('1.048'), 23.461538, 15.666667, 17.23077),
#  ('brinquedos', Decimal('1.869'), 31.754784, 20.72289, 24.926294),
#  ('perfumaria', Decimal('0.529'), 20.32258, 13.059908, 16.668203),
#  ('eletrodomesticos_2', Decimal('9.913'), 45.733334, 30.666666, 38.166668),
#  ('cds_dvds_musicais', Decimal('0.550'), 35.0, 15.0, 25.0),
#  ('fashion_bolsas_e_acessorios', Decimal('0.427'), 19.18139, 8.998822, 15.572438),
#  ('construcao_ferramentas_seguranca', Decimal('0.951'), 23.065933, 15.0, 18.989012),
#  ('fraldas_higiene', Decimal('1.038'), 25.0, 17.583334, 19.25)]

# %% [markdown]
# # Average Volume of Box for each Product Category

# %%
# %%sql
#
# with products_volume
# as
# ( select product_category, avg(volume)::real as avg_volume
#  from
#     (select product_category, (product_length_cm::real *product_height_cm::real *product_width_cm::real ) as volume
#     from products
#     where product_category is not null) as t
# group by product_category
# )
# select product_category, avg_volume, rank() over(order by avg_volume desc) as rank
# from products_volume;
# Out:
#  * postgresql://postgres:***@localhost/olist
# 73 rows affected.
# [('moveis_colchao_e_estofado', 77244.3, 1),
#  ('moveis_escritorio', 75468.47, 2),
#  ('moveis_cozinha_area_de_servico_jantar_e_jardim', 69406.09, 3),
#  ('eletrodomesticos_2', 55476.312, 4),
#  ('moveis_sala', 54486.13, 5),
#  ('moveis_quarto', 51038.844, 6),
#  ('pcs', 44635.168, 7),
#  ('agro_industria_e_comercio', 37604.23, 8),
#  ('industria_comercio_e_negocios', 37372.31, 9),
#  ('malas_acessorios', 32950.336, 10),
#  ('bebes', 30835.576, 11),
#  ('la_cuisine', 30483.4, 12),
#  ('casa_conforto', 28148.73, 13),
#  ('climatizacao', 27910.533, 14),
#  ('eletroportateis', 26913.238, 15),
#  ('instrumentos_musicais', 25089.021, 16),
#  ('portateis_casa_forno_e_cafe', 23911.613, 17),
#  ('cool_stuff', 23246.484, 18),
#  ('pet_shop', 22965.066, 19),
#  ('sinalizacao_e_seguranca', 22583.795, 20),
#  ('moveis_decoracao', 22481.225, 21),
#  ('utilidades_domesticas', 21904.168, 22),
#  ('casa_conforto_2', 20938.0, 23),
#  ('casa_construcao', 20800.236, 24),
#  ('brinquedos', 19625.812, 25),
#  ('construcao_ferramentas_iluminacao', 18897.256, 26),
#  ('portateis_cozinha_e_preparadores_de_alimentos', 18872.7, 27),
#  ('ferramentas_jardim', 18615.406, 28),
#  ('cama_mesa_banho', 18594.576, 29),
#  ('artigos_de_festas', 16942.73, 30),
#  ('automotivo', 16603.586, 31),
#  ('papelaria', 16240.033, 32),
#  ('construcao_ferramentas_construcao', 15455.385, 33),
#  ('esporte_lazer', 14725.349, 34),
#  ('artigos_de_natal', 13947.046, 35),
#  ('eletrodomesticos', 13451.751, 36),
#  ('construcao_ferramentas_jardim', 13399.671, 37),
#  ('cds_dvds_musicais', 13125.0, 38),
#  ('market_place', 12973.48, 39),
#  ('bebidas', 11217.803, 40),
#  ('artes', 10668.491, 41),
#  ('beleza_saude', 10468.159, 42),
#  ('seguros_e_servicos', 10233.5, 43),
#  ('fashion_roupa_masculina', 8798.421, 44),
#  ('fashion_calcados', 8478.208, 45),
#  ('fraldas_higiene', 8468.417, 46),
#  ('eletronicos', 7962.507, 47),
#  ('alimentos_bebidas', 7947.1636, 48),
#  ('fashion_roupa_infanto_juvenil', 7590.2, 49),
#  ('construcao_ferramentas_seguranca', 7472.055, 50),
#  ('construcao_ferramentas_ferramentas', 7357.6665, 51),
#  ('tablets_impressao_imagem', 7182.222, 52),
#  ('fashion_roupa_feminina', 7165.2593, 53),
#  ('pc_gamer', 7074.6665, 54),
#  ('cine_foto', 6952.393, 55),
#  ('consoles_games', 6898.9053, 56),
#  ('artes_e_artesanato', 6895.9473, 57),
#  ('fashion_esporte', 6789.8945, 58),
#  ('musica', 6727.4814, 59),
#  ('alimentos', 6634.122, 60),
#  ('informatica_acessorios', 6483.912, 61),
#  ('flores', 6334.857, 62),
#  ('perfumaria', 5136.2188, 63),
#  ('telefonia_fixa', 5018.681, 64),
#  ('audio', 4970.1724, 65),
#  ('fashion_underwear_e_moda_praia', 4584.132, 66),
#  ('fashion_bolsas_e_acessorios', 4480.635, 67),
#  ('livros_interesse_geral', 3900.0464, 68),
#  ('relogios_presentes', 3470.398, 69),
#  ('livros_tecnicos', 2758.992, 70),
#  ('livros_importados', 1935.3871, 71),
#  ('telefonia', 1865.8413, 72),
#  ('dvds_blu_ray', 1746.8541, 73)]

# %% [markdown]
# # Correlation between freight value and product weight, length, height, volume and price

# %%
# %%sql
#
# with products_data
# as
# (
#     select oi.freight_value,
#            oi.price,
#             product_weight_grams,
#             product_height_cm,
#             product_width_cm,
#             product_length_cm,
#             (product_height_cm::real * product_width_cm::real * product_length_cm::real) as volume
#     from order_items oi
#     join products p using(product_id)
# )
# select corr(freight_value,product_length_cm)::real as corr_length,
#         corr(freight_value,product_width_cm)::real as corr_width,
#         corr(freight_value,product_height_cm)::real as corr_height,
#         corr(freight_value,volume) as corr_volume,
#         corr(freight_value,product_weight_grams)::real as corr_weight,
#         corr(freight_value,price) as worr_price
# from products_data;
# Out:
#  * postgresql://postgres:***@localhost/olist
# 1 rows affected.
# [(0.30908597, 0.32377744, 0.39183104, 0.5872700708999319, 0.6104202, 0.4142043091015094)]

# %% [markdown]
# # Linear Relationship between freight value and product weight

# %%
# %%sql
#
# with products_data
# as (
#         select oi.freight_value, (product_weight_grams/1000)::real as weight
#         from products p
#         join order_items oi using(product_id)
#
# )
# select regr_slope(freight_value,weight)::real as slope_reg , regr_intercept(freight_value,weight)::real as intercept_reg
# from products_data;
# Out:
#  * postgresql://postgres:***@localhost/olist
# 1 rows affected.
# [(2.575215, 15.649705)]
